# %% [markdown]
# # ModSim Project 3
#
# Maia Materman and SeungU Lyu

# %%
# Configure Jupyter so figures appear in the notebook
# %matplotlib inline

# Configure Jupyter to display the assigned value after an assignment
# %config InteractiveShell.ast_node_interactivity='last_expr_or_assign'

# import functions from the modsim.py module
from modsim import *

# %% [markdown]
# ## Question
#
# Jupiter is the second heaviest planetary body in the solar system, right after the sun. Even though its mass is relatively small compared to the sun's mass (it is about 0.001% of the sun's mass), the impact it has on other planets in the solar system is huge. Even now, it attracts most of the asteroids in the solar system so that they cannot come toward the Earth. There was an interesting hypothesis that if Jupiter's mass was about 100 times higher than it was when it was created, it might have started nuclear fusion by itself and evolved into a star instead. If this had happened, the solar system could have become a binary star system which is actually common among many other stars in the universe.
#
# For this question, we thought it might be really interesting to see what would happen to the trajectories of the sun, Earth, and Jupiter if, for some reason, Jupiter started the nuclear fusion process and became a star with about the same mass as the sun. We thought the most fascinating trajectory might be Earth's and chose to focus on it in our analysis (but more on that later!)

# %% [markdown]
# ## Model
#
# In this model we decided to act as though the solar system had only three planetary masses, that of Earth, the sun and Jupiter. This lead to us examining the interactions of six forces which can be seen in our schematic below.
#
# <img src="Schematic.png" width=300 title="schematic">
#
# This model of the system allowed us to extrapolate a few equations which would make up the majority of our system. All of the equations were based around Newton's Law of Universal Gravitation:
#
# \begin{equation}
#     F_g = G \frac{m_1 m_2}{r^2}
# \end{equation}
#
# This law was the basis for all of our differential equations for the velocity of bodies in our system. Those equations took this form:
#
# \begin{equation}
#     \frac{dV}{dt} = \frac{F_{1\;2}}{m_1}+\frac{F_{1\;3}}{m_1}
# \end{equation}
#
# The numbers in this equation which are subscripts represent planetary bodies. For example, 1 could represent the Earth; 2, the sun; and 3, Jupiter.
#
# Before moving forward, it is essential to acknowledge some of the assumptions which these equations and other portions of our model introduce. As evidenced in our schematic, we chose to envision the solar system as if it only had three bodies. While doing this helped reduce some of the complexity of our model, it also makes it less accurate. It is also important to note that we had a bit of freedom as we were creating a model of a system which does not (yet?) exist in the physical space of our solar system. With that in mind, we were able to play with some parameters which have little basis in reality. One of those was the rate at which Jupiter grew in mass. We set it to grow linearly in most of our models, although we did also experiment with having it grow to the mass of the sun as soon as the simulation started as well as having it be as massive as the sun in the initial state. These were all modeling decisions which ended up influencing the outcome of our model (although we can't be sure how much they would impact the accuracy).

# %%
# setting the initial conditions for the model
r_e = 147e9
r_j = 778e9
init_jupiter_mass = 1.898e27

init = State(x_e = r_e, y_e = 0 , vx_e = 0 , vy_e = 29784,
             x_s = 0 , y_s = 0 , vx_s = 0 , vy_s = 0 ,
             x_j = r_j, y_j = 0 , vx_j = 0 , vy_j = 13069 , m_j = init_jupiter_mass)
# Out:
# x_e     1.470000e+11
# y_e     0.000000e+00
# vx_e    0.000000e+00
# vy_e    2.978400e+04
# x_s     0.000000e+00
# y_s     0.000000e+00
# vx_s    0.000000e+00
# vy_s    0.000000e+00
# x_j     7.780000e+11
# y_j     0.000000e+00
# vx_j    0.000000e+00
# vy_j    1.306900e+04
# m_j     1.898000e+27
# dtype: float64

# %%
# creating system object for the simulation
system = System(init=init,
                G=6.674e-11,
                m_s=1.989e30, 
                m_e=5.972e24,
                t_0=0,
                t_end= 37840000,
                m_j_init = 1.898e27,
                dt = 1000)
# Out:
# init        x_e     1.470000e+11
# y_e     0.000000e+00
# vx_e...
# G                                                   6.674e-11
# m_s                                                 1.989e+30
# m_e                                                 5.972e+24
# t_0                                                         0
# t_end                                                37840000
# m_j_init                                            1.898e+27
# dt                                                       1000
# dtype: object

# %%
# checking the rate of jupiter's mass increase
(1.989e+30 - 1.898e27)/system.t_end
# Out:
# 5.2513266384778014e+22

# %%
# Here's a function that computes the force of gravity

def universal_gravitation(state, system):
    """Computes gravitational force.
    
    state: State object with distance r
    system: System object with m1, m2, and G
    """
    x_e, y_e, vx_e, vy_e, x_s, y_s, vx_s, vy_s, x_j, y_j, vx_j, vy_j, m_j = state
    unpack(system)
    
    
    cur_position_se = Vector(x_s - x_e, y_s - y_e)
    mag_se = cur_position_se.mag
    
    force_se = G * m_s * m_e / mag_se**2
    direction_se = -cur_position_se.hat()
    
    se_force = direction_se * force_se
    
    
    
    cur_position_sj = Vector(x_s - x_j, y_s - y_j)
    mag_sj = cur_position_sj.mag
    
    force_sj = G * m_s * m_j / mag_sj**2
    direction_sj = -cur_position_sj.hat()
    
    sj_force = direction_sj * force_sj
    
    

    cur_position_je = Vector(x_j - x_e, y_j - y_e)
    mag_je = cur_position_je.mag
    
    force_je = G * m_j * m_e / mag_je**2
    direction_je = -cur_position_je.hat()
    
    je_force = direction_je * force_je
    
    
    return je_force, sj_force, se_force

# %%
# checking the function 
force = universal_gravitation(init,system)
# Out:
# (<Quantity([-1.89995577e+18 -0.00000000e+00], 'dimensionless')>,
#  <Quantity([ 4.16253597e+23 -0.00000000e+00], 'dimensionless')>,
#  <Quantity([ 3.6686486e+22 -0.0000000e+00], 'dimensionless')>)

# %% [markdown]
# Another thing we played with and iterated on was the way in which the sun was positioned in our system. In some of our first models, the sun is manipulated just by the forces at play in the system. The latter ones, however, reset the position of the sun each time the update function is called.

# %%
#updates current status not considering sun as 0,0 on the coordinate
def update_func(state, t, system):

    x_e, y_e, vx_e, vy_e, x_s, y_s, vx_s, vy_s, x_j, y_j, vx_j, vy_j, m_j = state
    unpack(system)    

    je_force, sj_force, se_force = universal_gravitation(state, system)
    dx_edt = vx_e
    dy_edt = vy_e
    dvx_edt = (-je_force.x / m_e) + (-se_force.x / m_e)
    dvy_edt = (-je_force.y / m_e) + (-se_force.y / m_e)
    
    dx_jdt = vx_j
    dy_jdt = vy_j
    dvx_jdt = (je_force.x / m_j) + (-sj_force.x / m_j)
    dvy_jdt = (je_force.y / m_j) + (-sj_force.y / m_j)
    
    dx_sdt = vx_s
    dy_sdt = vy_s
    dvx_sdt = (se_force.x / m_s) + (sj_force.x / m_s)
    dvy_sdt = (se_force.y / m_s) + (sj_force.y / m_s)
    
    x_e += dx_edt * dt
    y_e += dy_edt * dt
    vx_e += dvx_edt * dt
    vy_e += dvy_edt * dt
    
    x_s += dx_sdt * dt
    y_s += dy_sdt * dt
    vx_s += dvx_sdt * dt
    vy_s += dvy_sdt * dt
    
    x_j += dx_jdt * dt
    y_j += dy_jdt * dt
    vx_j += dvx_jdt * dt
    vy_j += dvy_jdt * dt
    if m_j < m_s:
        m_j += 5.250882589210215e+21 * dt
    
    return State(x_e = x_e, y_e = y_e, vx_e = vx_e, vy_e = vy_e, x_s = x_s, y_s = y_s, vx_s = vx_s, vy_s = vy_s, x_j = x_j, y_j = y_j, vx_j = vx_j, vy_j = vy_j, m_j = m_j)

# %% [markdown]
# This update function (update_func2) resets the sun's position each time which it is called.

# %%
#updates current status considering sun as 0,0 on the coordinate
def update_func2(state, t, system):

    x_e, y_e, vx_e, vy_e, x_s, y_s, vx_s, vy_s, x_j, y_j, vx_j, vy_j, m_j = state
    unpack(system)    

    je_force, sj_force, se_force = universal_gravitation(state, system)
    dx_edt = vx_e
    dy_edt = vy_e
    dvx_edt = (-je_force.x / m_e) + (-se_force.x / m_e)
    dvy_edt = (-je_force.y / m_e) + (-se_force.y / m_e)
    
    dx_jdt = vx_j
    dy_jdt = vy_j
    dvx_jdt = (je_force.x / m_j) + (-sj_force.x / m_j)
    dvy_jdt = (je_force.y / m_j) + (-sj_force.y / m_j)
    
    dx_sdt = vx_s
    dy_sdt = vy_s
    dvx_sdt = (se_force.x / m_s) + (sj_force.x / m_s)
    dvy_sdt = (se_force.y / m_s) + (sj_force.y / m_s)
    
    x_e += dx_edt * dt
    y_e += dy_edt * dt
    vx_e += dvx_edt * dt
    vy_e += dvy_edt * dt
    
    x_s += dx_sdt * dt
    y_s += dy_sdt * dt
    vx_s += dvx_sdt * dt
    vy_s += dvy_sdt * dt
    
    x_j += dx_jdt * dt
    y_j += dy_jdt * dt
    vx_j += dvx_jdt * dt
    vy_j += dvy_jdt * dt
    if m_j < m_s:
        m_j += 5.250882589210215e+21 * dt
    
    xs = x_s
    ys = y_s
    
    x_e -= xs
    y_e -= ys
    x_s -= xs
    y_s -= ys
    x_j -= xs
    y_j -= ys
    
    return State(x_e = x_e, y_e = y_e, vx_e = vx_e, vy_e = vy_e, x_s = x_s, y_s = y_s, vx_s = vx_s, vy_s = vy_s, x_j = x_j, y_j = y_j, vx_j = vx_j, vy_j = vy_j, m_j = m_j)

# %%
# running simulation with given system and update function
def run_simulation(system, update_func):
    """Runs a simulation of the system.
        
    system: System object
    update_func: function that updates state
    
    returns: TimeFrame
    """
    unpack(system)
    
    frame = TimeFrame(columns=init.index)
    frame.row[0] = init
    ts = linrange(t_0, t_end, dt)
    
    for t in ts:
        frame.row[t+dt] = update_func(frame.row[t], t, system)
    
    return frame

# %%
# plotting earth, sun, and jupiter according to the result
def plot_trajectory(results):
    plot(results.x_e, results.y_e, label='earth')
    plot(results.x_j, results.y_j, label='jupiter')
    plot(results.x_s, results.y_s, label='sun')

    
    decorate(xlabel='x position (m)',
             ylabel='y position (m)')

# %%
# first simulation to check what happens during short interval of time (about a year) to the solar system
# %time results1 = run_simulation(system, update_func)
# Out:
# Wall time: 8min 20s

# %%
plot_trajectory(results1)
decorate(title='Sun, Earth, Jupiter Trajectory for "1+1/4 years"')

# %% [markdown]
# The first model was tested to check whether the simulation is working as expected. The simulation ran for the period of 37840000 seconds, which is about 1 and a quarter years. This model shows the linear growth of Jupiter's mass for a time span of twelve years, so the pull made by Jupiter isn't very strong yet. However, we can already see the earth being pulled a little bit by Jupiter, making a larger circle as it orbits the sun.

# %%
system.init.m_j = system.m_s
# %time results1_i = run_simulation(system, update_func)
# Out:
# Wall time: 8min 34s

# %%
plot_trajectory(results1_i)
decorate(title='Sun, Earth, Jupiter Trajectory for "1 1/4 years"')

# %% [markdown]
# The second model tested what happens when Jupiter's mass is increased instantaneously to be the same mass as the sun. We can see from the trajectories that the force of Jupiter's new gravity is enough to pull both the sun and Earth at the same time.

# %% [markdown]
# We did some experimenting with the orientation of our planets as well. Each system depicts a different orientation of the bodies, one with the sun, Earth and Jupiter in a straight line on a single side and one with Jupiter and the Earth on opposing sides of the sun. Each of those is shown below.
#
# #### This is the orientation of the bodies on the same side of the sun
# <img src="InLine.png" width=300 title="PlanetaryBodiesinLine">
#
# #### This is the orientation of the bodies on opposite sides of the sun
# <img src="Opposite.png" width=300 title="PlanetaryBodiesonOppositeSides">
#
# The model in the cell directly below this one shows the masses on a single side, while the system defined about five cells below it models the system with the Earth on one side of the sun and Jupiter on the other.

# %%
init = State(x_e = r_e, y_e = 0 , vx_e = 0 , vy_e = 29784,
             x_s = 0 , y_s = 0 , vx_s = 0 , vy_s = 0 ,
             x_j = r_j, y_j = 0 , vx_j = 0 , vy_j = 13069 , m_j = init_jupiter_mass)

system = System(init=init,
                G=6.674e-11,
                m_s=1.989e30, 
                m_e=5.972e24,
                t_0=0,
                t_end= 378400000,
                m_j_init = 1.898e27,
                dt = 10000)
# Out:
# init        x_e     1.470000e+11
# y_e     0.000000e+00
# vx_e...
# G                                                   6.674e-11
# m_s                                                 1.989e+30
# m_e                                                 5.972e+24
# t_0                                                         0
# t_end                                               378400000
# m_j_init                                            1.898e+27
# dt                                                      10000
# dtype: object

# %% [markdown]
# The initial state and system was set so that it simulates the orientation of the bodies on the same side of the sun.

# %%
# %time results2 = run_simulation(system, update_func)
# Out:
# Wall time: 8min 22s

# %%
plot_trajectory(results2)
decorate(title='Sun, Earth, Jupiter Trajectory "12 years"')

# %% [markdown]
# Finally, we ran the simulation for twelve years. Since Jupiter's mass is increasing over time and at some point, it is heavy enough to have an impact on the sun's movement, the trajectories look rather like a random scribble than a balanced orbit. Since it is almost impossible to identify anything with these trajectories, the second update function where every orbit is re-organized relative to sun's coordinate was used in the next simulation to get a better view about what is happening.

# %%
# %time results3 = run_simulation(system, update_func2)
# Out:
# Wall time: 8min 26s

# %%
plot_trajectory(results3)
decorate(title='Sun, Earth, Jupiter Trajectory "12 years"')

# %% [markdown]
# The orbit looks much better now, being able to explain what is happening. As Jupiter's mass increases, Jupiter and the sun pull each other with their respective forces of gravity, narrowing the space between them. Because of the intense gravity, the Earth is flung outside the solar system at some point, not being able to hold its original orbit around the sun. After Earth lost it's track, it looks rather unaffected by either the sun or Jupiter's gravity due to its far distance.

# %%
system.init.m_j = system.m_s
# %time results3_i = run_simulation(system, update_func2)
# Out:
# Wall time: 8min 18s

# %%
plot_trajectory(results3_i)
decorate(title='Sun, Earth, Jupiter Trajectory "12 years"')

# %% [markdown]
# We did another simulation where we increased Jupiter's mass instantaneously. One interesting thing is that Jupiter's orbit balances out rather quickly, creating a balanced orbit with the sun. However, Earth is still kicked out of the solar system (or the new Sol-Jupiter system) at some point, not being able to come back to its original position.

# %%
init = State(x_e = r_e, y_e = 0 , vx_e = 0 , vy_e = 29784,
             x_s = 0 , y_s = 0 , vx_s = 0 , vy_s = 0 ,
             x_j = -r_j, y_j = 0 , vx_j = 0 , vy_j = -13069 , m_j = init_jupiter_mass)

system = System(init=init,
                G=6.674e-11,
                m_s=1.989e30, 
                m_e=5.972e24,
                t_0=0,
                t_end= 378400000,
                m_j_init = 1.898e27,
                dt = 10000)
# Out:
# init        x_e     1.470000e+11
# y_e     0.000000e+00
# vx_e...
# G                                                   6.674e-11
# m_s                                                 1.989e+30
# m_e                                                 5.972e+24
# t_0                                                         0
# t_end                                               378400000
# m_j_init                                            1.898e+27
# dt                                                      10000
# dtype: object

# %% [markdown]
# This time, the initial state and system was set so that it simulates the orientation of the bodies on opposite sides of the sun.

# %%
# %time results4 = run_simulation(system, update_func)
# Out:
# Wall time: 7min 41s

# %%
plot_trajectory(results4)
decorate(title='Sun, Earth, Jupiter Trajectory "12 years"')

# %% [markdown]
# Again, just looking at the trajectories without any further modification seems hard to understand.

# %%
# %time results5 = run_simulation(system, update_func2)
# Out:
# Wall time: 7min 44s

# %%
plot_trajectory(results5)
decorate(title='Sun, Earth, Jupiter Trajectory "12 years"')

# %% [markdown]
# After modifying the coordinates so that it is always relative to the sun's movement, it looks like though that earth is able to hold to its orbit longer than the former simulation. However, it looks like it will still be kicked out of the orbit according to the trajectory earth draws at the end.

# %%
system.init.m_j = system.m_s
# %time results5_i = run_simulation(system, update_func2)
# Out:
# Wall time: 7min 59s

# %%
plot_trajectory(results5_i)
decorate(title='Sun, Earth, Jupiter Trajectory "12 years"')

# %% [markdown]
# We again implemented simulation where Jupiter's mass is increased instantaneously, and the orbit seems fairly similiar to the simulation we did above with other orientation, but looking at the x position, we can see that for this simulation the Earth was shot out of the solar system with much faster speed compared to the previous experiment. It seems that velocity of the Earth is greatly affected by the initial orientation of Jupiter and Earth.

# %% [markdown]
# ## Results
#
# The answer to our question is depicted in each plot of the bodies. In most of the models, Earth has a trajectory which appears fairly random due to two other massive gravity pulling it at different directions. In each model, however, Earth is flung out of the solar system, not being able to hold itself into the original orbit or find a new trajectory that it can orbit around. Interestingly, the velocity of earth being shoot out of the system seems to vary according to its original orientation with the jupiter. The time which that takes also varies by the factors which we manipulated in our simulation. It is reasonable due to the fact that even in the real world, it is hard for a planet to find it's orbit around a binary star system due to the complex factors related to their orbits. Since the simulation is trying to change the solar system into a binary star system, the Earth has to meet the perfect start position and velocity in order to make a new orbit around two stars. It might be really interesting to find out these optimal values by sweeping different variables.

# %% [markdown]
# ## Interpretation
#
# This notebook contains very visible iterations on our original model. The first model shown is representative of the first simulation we did and every subsequent plot depicts an iteration on that original idea. We first played with the placement of the sun in the system, then how Jupiter increases in size and finally on the orientation of the planets.
#
# From the result, we learned that it is fairly hard for a planet to set an orbit around two massive body of objects, or stars due to their massive gravity. Fast or slow, the earth will eventually become a 'rogue planet' roaming around the universe without any star to orbit around. Even if we find out the optimal values that will set earth balanced in between sun and jupiter, it is likely that all the organisms on Earth are already dead even before due to a huge change in gravity.
#
# Our model is definitely far from perfect. Although we look at a few parameters and how they relate to the system, we essentially look at them in isolation. It would have been valuable to sweep over a range of values for each thing which we decided to change in our model. It also would have been interesting to see the time that the Earth was flung out of the solar system since it does that in every simulation. We also could have done more to specify our question and build our model around it. Our question is fairly broad, so making a more exact question which could have been more easily measured probably would have been beneficial.
#
# The one biggest issue we had was the amount of time it took to finish a simulation. Since there were a lot of things happening every second for our simulation, we couldn't change the step size 'dt' into high values such as 100,000 because it changed the result of simulation too much. In the same way, our simulation with a dt size of 10000 might be not accurate enough, but we had to compromise with the value because each simulation took about 8~10 minutes, and it was too long already to play around with different iterations. If time wasn't the biggest issue, we could have tried many iterations to test out different questions.
